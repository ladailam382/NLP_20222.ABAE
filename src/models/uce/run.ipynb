# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/NLP_UCE/requirements.txt

# %%
# !pip3 install Cython

# %%
# %cd /content/drive/MyDrive/NLP_UCE/

# %run main.py --train_data "/content/drive/MyDrive/NLP_UCE/Data/CitySearch/train_skipgram_embedding_dim_200.zip" \
--test_data "/content/drive/MyDrive/NLP_UCE/Data/CitySearch/test_se.zip" \
--seed_data "/content/drive/MyDrive/NLP_UCE/Data/seed_word/city_search_seed_word.txt" \
--w2v "/content/drive/MyDrive/NLP_UCE/Data/CitySearch/skipgram_embedding_dim_200" \
--lr 0.00001 \
--anpha 1 \
--lamda 0 \
--is_train 1 \
--batchsize 512 \
--n_epoch 10 \
--des "" \
--start_epoch 0 \
--maxlen 30 \
--save_initmodel 0 \
--threshold 1 \
--number_loss 0 \
--phi 0 \
--maxlen_seed 5 \
--num_cluster_general 200 \
--num_cluster_aspects 1 \
--maxlen_seed_aspects 5 \
--general_idx 80
# --pretrain_model "/content/drive/MyDrive/Aspect-base_SA/code1/WMF/save_model/Restaurant-Jasenfscore=0.6772116185025194epoch=20use_att=False"
# Out:
# /content/drive/MyDrive/NLP_UCE
# Namespace(des='', n_epoch=10, train_data='/content/drive/MyDrive/NLP_UCE/Data/CitySearch/train_skipgram_embedding_dim_200.zip', test_data='/content/drive/MyDrive/NLP_UCE/Data/CitySearch/test_se.zip', val_data=None, seed_data='/content/drive/MyDrive/NLP_UCE/Data/seed_word/city_search_seed_word.txt', w2v='/content/drive/MyDrive/NLP_UCE/Data/CitySearch/skipgram_embedding_dim_200', aspect_label=None, maxlen=30, maxlen_seed=5, batchsize=512, start_epoch=0, word_emb_dropout=0, word_emb_froze_teacher=True, word_emb_froze_student=False, use_att_seed_student=0, use_att_seed_teacher=0, use_att_sent=0, lr=1e-05, anpha=1.0, beta=0, weight_teacher=None, weight_student=None, lamda=0.0, path_save_model='/content/', pretrain_model=None, is_train=1, threshold=1.0, save_initmodel=0, number_loss=0, phi=0.0, low_prior=0, high_prior=1, num_cluster_general=200, num_cluster_aspects=1, general_idx=80, maxlen_seed_aspects=5)
# ...

# %%
b = torch.load("/content/drive/MyDrive/NLP_UCE/result.zip")

# %%
b[20:40]
# Out:
# [['two wasted steak crime',
#   [0.40872422897455624, 0.30206646685270033, 0.2892093041727434],
#   0,
#   0],
#  ['staff bit friendly',
#   [0.3358217939697015, 0.33963411710678965, 0.3245440889235089],
#   1,
#   1],
#  ['think meatball parm good',
#   [0.2970809497334671, 0.33498456044807906, 0.36793448981845384],
#   0,
#   0],
#  ['want good tasting well seasoned latin food eat cabana go wrong',
#   [0.36874600539769664, 0.31346996382411063, 0.3177840307781927],
#   0,
#   0],
#  ['definitely try taglierini truffle incredible',
#   [0.2187225896224643, 0.48669052116419476, 0.2945868892133409],
#   0,
#   0],
#  ['also staff attentive really personable',
#   [0.43834651335515556, 0.28005754725244664, 0.2815959393923978],
#   1,
#   1],
#  ['gnocchi literally melt mouth',
#   [0.34922605068711526, 0.32011398295283017, 0.33065996636005457],
#   0,
#   0],
#  ['entree include classic like lasagna fettuccine alfredo chicken parmigiana',
# ...
